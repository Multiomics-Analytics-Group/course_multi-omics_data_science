# %% [markdown]
# # Running Nextflow from Colab
#
# This is a guide with code to be able to run nf-core pipelines from colab notebooks.

# %%
# !apt update
# !apt install openjdk-17-jdk
# !export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# !export PATH=$JAVA_HOME/bin:$PATH
# !source ~/.bashrc
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 https://cli.github.com/packages stable InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,123 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,824 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# ## Installing Nextflow

# %%
# !wget -qO- https://get.nextflow.io | bash # Download Nextflow
# !mv nextflow /usr/bin/nextflow # Move to a path Colab can access
# !chmod +x /usr/bin/nextflow # Make it executable
# !nextflow -v # Test it
# Out:
#       N E X T F L O W
#       version 25.10.0 build 10289
#       created 22-10-2025 16:26 UTC
#       cite doi:10.1038/nbt.3820
#       http://nextflow.io
#
#
# Nextflow installation completed. Please note:
# - the executable file `nextflow` has been created in the folder: /content
# - you may complete the installation by moving it to a directory in your $PATH
#
# nextflow version 25.10.0.10289

# %% [markdown]
# ## Setting up Conda

# %%
# !pip install -q condacolab # -q here means quite
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !conda config --add channels bioconda
# !conda config --add channels conda-forge
# !conda config --add channels defaults
# !conda config --set channel_priority strict

# %% [markdown]
# ## Running a Test pipeline

# %%
#! nextflow pull nf-core/demo

# %%
#! nextflow run nf-core/demo -profile conda,test --outdir demo-results

# %% [markdown]
# # Running QuantMS pipeline
#
# ![QuantMS pipeline](https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/notebooks/img/quantms.png)

# %% [markdown]
# ### Creating Data Folders for Metagenomics Analysis

# %%
# !mkdir proteomics
# !mkdir proteomics/data
# !mkdir proteomics/databases
# Out:
# mkdir: cannot create directory ‘proteomics’: File exists
# mkdir: cannot create directory ‘proteomics/data’: File exists
# mkdir: cannot create directory ‘proteomics/databases’: File exists

# %% [markdown]
# ### Downloading Sample Sheet and Database File for nf-core/QuantMS

# %%
! wget https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/data/experiment_design.tsv -O proteomics/data/sample_sheet.tsv
! wget https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/database/proteindatabase.fasta -O proteomics/databases/proteindatabase.fasta
# Out:
# --2025-11-07 12:32:41--  https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/data/experiment_design.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 308 [text/plain]
# Saving to: ‘proteomics/data/sample_sheet.tsv’
#
# proteomics/data/sam 100%[===================>]     308  --.-KB/s    in 0s
#
# 2025-11-07 12:32:41 (6.54 MB/s) - ‘proteomics/data/sample_sheet.tsv’ saved [308/308]
#
# --2025-11-07 12:32:41--  https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/database/proteindatabase.fasta
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# ...

# %%
! wget https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/low_resources.config -O proteomics/low_resources.config
# Out:
# --2025-11-07 12:52:31--  https://raw.githubusercontent.com/Multiomics-Analytics-Group/course_multi-omics_data_science/refs/heads/main/proteomics/low_resources.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8425 (8.2K) [text/plain]
# Saving to: ‘proteomics/low_resources.config’
#
# proteomics/low_reso 100%[===================>]   8.23K  --.-KB/s    in 0.001s
#
# 2025-11-07 12:52:31 (8.17 MB/s) - ‘proteomics/low_resources.config’ saved [8425/8425]

# %%
# !wget https://zenodo.org/records/17549994/files/160513-SM-AHYMJ-14.mzML?download=1 -O proteomics/data/160513-SM-AHYMJ-14.mzML
# !wget https://zenodo.org/records/17549994/files/160914_SM-9SD9G_284.mzML?download=1 -O proteomics/data/160914_SM-9SD9G_284.mzML
# !wget https://zenodo.org/records/17549994/files/160920_SM-AKTWT_509.mzML?download=1 -O proteomics/data/160920_SM-AKTWT_509.mzML
# !wget https://zenodo.org/records/17549994/files/160928_SM-6ZEWG_423.mzML?download=1 -O proteomics/data/160928_SM-6ZEWG_423.mzML
# Out:
# --2025-11-07 11:05:29--  https://zenodo.org/records/17549994/files/160513-SM-AHYMJ-14.mzML?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.153, 188.185.48.75, 137.138.52.235, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 461672605 (440M) [application/octet-stream]
# Saving to: ‘proteomics/data/160513-SM-AHYMJ-14.mzML’
#
# proteomics/data/160 100%[===================>] 440.29M  1.80MB/s    in 2m 17s
#
# 2025-11-07 11:07:46 (3.22 MB/s) - ‘proteomics/data/160513-SM-AHYMJ-14.mzML’ saved [461672605/461672605]
#
# --2025-11-07 11:07:47--  https://zenodo.org/records/17549994/files/160914_SM-9SD9G_284.mzML?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.75, 137.138.52.235, 188.185.43.153, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 311793888 (297M) [application/octet-stream]
# ...

# %%
! nextflow pull nf-core/quantms
# Out:
# Checking nf-core/quantms ...
#  downloaded from https://github.com/nf-core/quantms.git - revision: 38e08da5b4 [master]

# %%
! nextflow run nf-core/quantms --input ./proteomics/data/sample_sheet.tsv --database ./proteomics/databases/proteindatabase.fasta --outdir ./proteomics/results -profile conda -c proteomics/low_resources.config -resume
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
#
#  N E X T F L O W   ~  version 25.10.0
#
# Launching `https://github.com/nf-core/quantms` [compassionate_noether] DSL2 - revision: 38e08da5b4 [master]
#
# WARN: ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   There is a problem with your Conda configuration!
#
#   You will need to set-up the conda-forge and bioconda channels correctly.
#   Please refer to https://bioconda.github.io/
#   The observed channel order is
#   [defaults, conda-forge, bioconda]
#   but the following channel order is required:
#   [conda-forge, bioconda, defaults]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
# ...
